# %%
import pandas as pd
import numpy as np

data = {
    "Customer_ID": [
        "C001", "C002", "C003", "C004", "C005",
        "C006", "C007", "C008", "C009", "C010",
        "C011", "C012", "C013", "C014", "C015",
        "C016", "C017", "C018", "C019", "C020",
        "C021", "C022", "C023", "C024", "C025",
        "C026", "C027", "C028", "C029", "C030"
    ],

    "Age": [
        23, 35, 29, 42, 26, 31, 45, 28, 38, 24,
        33, 27, 41, 36, 22, 30, 39, 25, 44, 32,
        28, 37, 46, 21, 34, 40, 27, 43, 31, 36
    ],

    "Annual_Income": [
        28000, 62000, 45000, 85000, 32000,
        52000, 92000, 41000, 68000, 30000,
        58000, 38000, 78000, 65000, 24000,
        49000, 72000, 29000, 88000, 55000,
        43000, 70000, 95000, 22000, 60000,
        82000, 36000, 90000, 51000, 67000
    ],

    "Spending_Score": [
        82, 48, 75, 35, 88,
        62, 28, 78, 45, 85,
        55, 72, 38, 50, 92,
        68, 42, 80, 25, 58,
        76, 40, 22, 95, 52,
        30, 84, 20, 65, 47
    ],

    "Purchase_Frequency": [
        15, 8, 12, 5, 18,
        10, 4, 13, 7, 16,
        9, 11, 6, 8, 20,
        12, 7, 14, 3, 10,
        13, 6, 4, 21, 9,
        5, 15, 3, 11, 8
    ],

    "Average_Order_Value": [
        1800, 3200, 2400, 4500, 1500,
        2800, 5200, 2100, 3600, 1400,
        3000, 1900, 4100, 3500, 1200,
        2600, 3800, 1600, 5000, 2900,
        2300, 3700, 5500, 1100, 3100,
        4600, 1700, 4900, 2700, 3400
    ],

    "Website_Visits": [
        45, 22, 38, 15, 52,
        31, 10, 40, 25, 48,
        28, 35, 18, 24, 58,
        36, 20, 43, 8, 30,
        42, 19, 12, 62, 27,
        16, 46, 9, 34, 23
    ],

    "Total_Purchases": [
        20, 10, 16, 7, 24,
        14, 5, 18, 9, 22,
        12, 15, 8, 11, 27,
        16, 9, 19, 4, 13,
        17, 8, 6, 28, 12,
        7, 21, 5, 15, 10
    ]
}

df=pd.DataFrame(data)
print(df)
# Out:
#    Customer_ID  Age  Annual_Income  Spending_Score  Purchase_Frequency  \
# 0         C001   23          28000              82                  15
# 1         C002   35          62000              48                   8
# 2         C003   29          45000              75                  12
# 3         C004   42          85000              35                   5
# 4         C005   26          32000              88                  18
# 5         C006   31          52000              62                  10
# 6         C007   45          92000              28                   4
# 7         C008   28          41000              78                  13
# 8         C009   38          68000              45                   7
# 9         C010   24          30000              85                  16
# 10        C011   33          58000              55                   9
# 11        C012   27          38000              72                  11
# ...
